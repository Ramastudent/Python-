# %%
#harshad number
a=str(45)
sum=0
for i in (a):
  sum+=int(i)
  print(sum)
if (int(a)%sum==0):
  print('harshad number')
else:
  print('not harshad number')
# Out:
# 4
# 9

# %%
#automarphic number
a=76
b=str(a**2)
m=len(str(b))
c=(b[-len(str(a)):])
if str(a)==c:
    print('is automorphic number')
else:
    print('not automorphic')
# Out:
# is automorphic number

# %%
def wish():
  print("Hello Good Morning")
  wish()
  wish()
  wish()

# %%
def wish(name):
  print("hello",name,"good morning")
wish("rama")
wish("neha")
# Out:
# hello rama good morning
# hello neha good morning

# %%
def squareit(number):
  print("squareof",number,"is",number*number)
squareit(2)
squareit(4)
# Out:
# squareof 2 is 4
# squareof 4 is 16

# %%
def add(x,y):
  return x+y
  result=add(10,20)
  print("the sum is",add(10,20))

# %%
def even_odd(num):
  if num%2==0:
    print('even number')
  else:
    print('odd number')
even_odd(2)
even_odd(3)
# Out:
# even number
# odd number

# %%
def fact(num):
  result=1
  while num>=1:
    result=result*num
    num=num-1
  return result
for i in range(1,5):
  print("the factorial",i,"is",fact(i))
# Out:
# the factorial 1 is 1
# the factorial 2 is 2
# the factorial 3 is 6
# the factorial 4 is 24

# %%
class Bank():
  Bank_name='ABC'
  ifsc_code='ABC123'
  def __init__(self,account_name,account_number,money):
    self.account_name=account_name
    self.account_number=account_number
    self.money=money
obj=Bank('ABC','12345','1000')
print((obj.__dict__))
# Out:
# {'account_name': 'ABC', 'account_number': '12345', 'money': '1000'}

# %%
class Demo:
  def __init__(self,a):
    self.a=a
  def __add__(self,other):
     return self.a+other.a
obj1=Demo(2)
print(obj1.__dict__)
obj2=Demo(4)
print(obj2.__dict__)
print(obj1+obj2)
# Out:
# {'a': 2}
# {'a': 4}
# 6

# %%
class Bank:
  bank_name='SBI'
  ifsc='ABCD123'
  def __init__(self,name,money,bank_num):
    self.password='Ram123'
    self.name=name
    self.bank_num=bank_num
    self.money=money
  def balance_enjquiry(self):
    print('money in ur account is {}'.format(self.money))
  def saving(self,amount):
    self.money+=amount
    print('{} is added in ur account {}.total is{}'.format(amount,self.bank_num,self.money))
  def withdral(self,amount):
    self.money+=amount
    print('{} is withdral into ur account {}.total is {}'.format(amount,self.bank_num,self.money))
bank_obj=Bank('rama chandra','1432',10000)
print('welcome to.format(Bank.bank_name)')


user_password=(input('enetr the password :'))

if user_password==bank_obj.password:
  type_op=input('''enter 1 for the balance enquiry
  enter 2 for saving
  enter 3 for the withdral''')

  if type_op=='1':
    bank_obj.balance_enquiry()
  elif type_op=='2':
    amount=int(input('enter the amount for saving'))
    bank_obj.saving(amount)
  else:
    amount=int(input('enter the ampount for withdral'))
    bank_obj.withdral(amount)
else:
  print('wrong password')
# Out:
# welcome to.format(Bank.bank_name)
# enetr the password :1432
# wrong password
